# %%
import pandas as pd
import numpy as np
import ast
import nltk

# %%
data = pd.read_csv('barterdata.csv')

# %%
data.head(50)
# Out:
#                                          Title Name  View Count  Like Count  \
# 0                        Visual identity. Branding.        6845         933
# 1                  Thomas Edisons Invention Factory        5997         224
# 2                 Hellorep.ai onboarding experience        1510        1080
# 3                                    3D Composition         739         930
# 4                                    3D Composition        4647         384
# 5                      Medical service - Mobile app        9456         474
# 6                                Blent | Case Study        6603        1722
# 7                        Visual identity. Branding.        1644         769
# 8                  Thomas Edisons Invention Factory        9940         722
# 9                                Blent | Case Study        8031         929
# 10  Logo Update for Web3 Platform (Unused for Sale)        5728         147
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title Name  10000 non-null  object
#  1   View Count  10000 non-null  int64
#  2   Like Count  10000 non-null  int64
#  3   Tags        10000 non-null  object
#  4   Category    10000 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 390.8+ KB

# %%
data.head(1)Title.values
# Out:
#   File "/var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/418600557.py", line 1
#     data.head(1)Title.values
#                 ^
# SyntaxError: invalid syntax

# %%
data.head(1)['Title'].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data.head(1)['Title Name'].values
# Out:
# array(['Visual identity. Branding.'], dtype=object)

# %%
data.head(1)['View Count'].values
# Out:
# array([6845])

# %%
data.head(1)['Tags'].values
# Out:
# array(["Logo', 'Package', 'Motion Graphics', 'Product', 'Character'"],
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# Title Name    0
# View Count    0
# Like Count    0
# Tags          0
# Category      0
# dtype: int64

# %%
data2 = data.drop(columns=['View Count','Like Count'])

# %%
data2
# Out:
#                              Title Name  \
# 0            Visual identity. Branding.
# 1      Thomas Edisons Invention Factory
# 2     Hellorep.ai onboarding experience
# 3                        3D Composition
# 4                        3D Composition
# ...                                 ...
# 9995                 Blent | Case Study
# 9996      Cryptomate: Wallet App design
# 9997         Visual identity. Branding.
# 9998  Hellorep.ai onboarding experience
# 9999                 Blent | Case Study
#
#                                                    Tags               Category
# 0     Logo', 'Package', 'Motion Graphics', 'Product'...   Environmental Design
# 1     Comic Book', 'Character', 'Poster', 'Illustrat...            Logo Design
# 2     Web Design', 'Character', 'Magazine', 'Motion ...    Vehicle Wrap Design
# 3     Illustration', 'Package', 'Character', 'Magazi...  Brand Identity Design
# 4     Comic Book', 'Typography', 'Web Design', 'Maga...           Illustration
# ...

# %% [raw]
# data2.dulpicated().sum()

# %%
data2.duplicated().sum()
# Out:
# 3

# %%
duplicates= data2[data2.duplicated()]

# %%
duplicates
# Out:
#                              Title Name  \
# 5597  Hellorep.ai onboarding experience
# 5770                     3D Composition
# 6952         Visual identity. Branding.
#
#                                             Tags             Category
# 5597         Poster', 'Comic Book', 'Typography'  Vehicle Wrap Design
# 5770               Character', 'Poster', 'UI/UX'            Animation
# 6952  Illustration', 'Motion Graphics', 'Poster'        Poster Design

# %%
data2.head(50)
# Out:
#                                          Title Name  \
# 0                        Visual identity. Branding.
# 1                  Thomas Edisons Invention Factory
# 2                 Hellorep.ai onboarding experience
# 3                                    3D Composition
# 4                                    3D Composition
# 5                      Medical service - Mobile app
# 6                                Blent | Case Study
# 7                        Visual identity. Branding.
# 8                  Thomas Edisons Invention Factory
# 9                                Blent | Case Study
# 10  Logo Update for Web3 Platform (Unused for Sale)
# 11                      News Website Design Concept
# 12                               Letter.co Branding
# 13                    Cryptomate: Wallet App design
# 14                       Visual identity. Branding.
# 15                      News Website Design Concept
# 16         Brainwave AI UI Kit - Add New List Modal
# ...

# %%
def converter(obj):
    L=[]
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
data2['Tags']= data['Tags'].apply(converter)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/Anushka/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/2422780157.py", line 1, in <module>
#     data2['Tags']= data['Tags'].apply(converter)
#
#   File "/Users/Anushka/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 4433, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
#   File "/Users/Anushka/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1088, in apply
#     return self.apply_standard()
#
#   File "/Users/Anushka/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py", line 1143, in apply_standard
#     mapped = lib.map_infer(
#
#   File "pandas/_libs/lib.pyx", line 2870, in pandas._libs.lib.map_infer
#
# ...

# %%
data2 = data2[data2.duplicated()]

# %%
data2['Title Name']= data2['Title Name'].apply(lamba x:[i.replace(" ","")for i in x] )
# Out:
#   File "/var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/193597931.py", line 1
#     data2['Title Name']= data2['Title Name'].apply(lamba x:[i.replace(" ","")for i in x] )
#                                                          ^
# SyntaxError: invalid syntax

# %%
import string

def remove_punctuation(text):
    return ''.join(char for char in text if char not in string.punctuation)

# Example list
my_list = ["Hello!", "How are you?", "I'm doing well."]

# Apply the function to each element in the list
cleaned_list = [remove_punctuation(item) for item in my_list]

print(cleaned_list)
# Out:
# ['Hello', 'How are you', 'Im doing well']

# %%
data2['Title Name'].head(50)
# Out:
# 0                          Visual identity. Branding.
# 1                    Thomas Edisons Invention Factory
# 2                   Hellorep.ai onboarding experience
# 3                                      3D Composition
# 4                                      3D Composition
# 5                        Medical service - Mobile app
# 6                                  Blent | Case Study
# 7                          Visual identity. Branding.
# 8                    Thomas Edisons Invention Factory
# 9                                  Blent | Case Study
# 10    Logo Update for Web3 Platform (Unused for Sale)
# 11                        News Website Design Concept
# 12                                 Letter.co Branding
# 13                      Cryptomate: Wallet App design
# 14                         Visual identity. Branding.
# 15                        News Website Design Concept
# 16           Brainwave AI UI Kit - Add New List Modal
# ...

# %%
def remove_punctuation(text):
    return ''.join(char for char in text if char not in string.punctuation)

# Example usage
text = "Visual identity. Branding."
cleaned_text = remove_punctuation(text)

print(cleaned_text)
# Out:
# Visual identity Branding

# %%
data2['Title Name'] = data2['Title Name'].apply(remove_punctuation)

# %%
data2['Title Name'].head(60)
# Out:
# 0                     VisualidentityBranding
# 1              ThomasEdisonsInventionFactory
# 2             Hellorepaionboardingexperience
# 3                              3DComposition
# 4                              3DComposition
# 5                    MedicalserviceMobileapp
# 6                             BlentCaseStudy
# 7                     VisualidentityBranding
# 8              ThomasEdisonsInventionFactory
# 9                             BlentCaseStudy
# 10    LogoUpdateforWeb3PlatformUnusedforSale
# 11                  NewsWebsiteDesignConcept
# 12                          LettercoBranding
# 13                 CryptomateWalletAppdesign
# 14                    VisualidentityBranding
# 15                  NewsWebsiteDesignConcept
# 16           BrainwaveAIUIKitAddNewListModal
# 17                          LettercoBranding
# 18                     illustrationanimation
# 19                     illustrationanimation
# 20            Hellorepaionboardingexperience
# ...

# %%
def remove_spaces(text):
    return ''.join(text.split())

# Example usage
text = "Visual identity. Branding."
cleaned_text = remove_spaces(text)

print(cleaned_text)
# Out:
# Visualidentity.Branding.

# %%
data2['Title Name'] = data2['Title Name'].apply(remove_spaces)

# %%
data2['Tags']=data2['Tags'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
data2['Tags']=data['Tags']

# %%
data2['Tags'].apply(remove_punctuation)
# Out:
# 0          Logo Package Motion Graphics Product Character
# 1       Comic Book Character Poster Illustration Brand...
# 2       Web Design Character Magazine Motion Graphics ...
# 3       Illustration Package Character Magazine Brandi...
# 4               Comic Book Typography Web Design Magazine
#                               ...
# 9995    Illustration Product Animation Package Social ...
# 9996           Social Media Branding Logo Motion Graphics
# 9997                   Package Web Design Motion Graphics
# 9998    UIUX Package Web Design Magazine Character Soc...
# 9999    Poster Animation Comic Book Motion Graphics So...
# Name: Tags, Length: 10000, dtype: object

# %%
def remove_punctuation_except_comma(text):
    punctuation = string.punctuation.replace(',', '')  # Remove comma from punctuation
    return ''.join(char for char in text if char not in punctuation)

# %%
data2['Tags']=data2['Tags'].apply(remove_punctuation_except_comma)

# %%
data2['Tags'] = data2['Tags'].apply(remove_spaces)

# %%
data2['Title Name']= data['Title Name']

# %%
data2['Title Name'].head(60)
# Out:
# 0                          Visual identity. Branding.
# 1                    Thomas Edisons Invention Factory
# 2                   Hellorep.ai onboarding experience
# 3                                      3D Composition
# 4                                      3D Composition
# 5                        Medical service - Mobile app
# 6                                  Blent | Case Study
# 7                          Visual identity. Branding.
# 8                    Thomas Edisons Invention Factory
# 9                                  Blent | Case Study
# 10    Logo Update for Web3 Platform (Unused for Sale)
# 11                        News Website Design Concept
# 12                                 Letter.co Branding
# 13                      Cryptomate: Wallet App design
# 14                         Visual identity. Branding.
# 15                        News Website Design Concept
# 16           Brainwave AI UI Kit - Add New List Modal
# ...

# %%
data2['Category'].head(60)
# Out:
# 0          Environmental Design
# 1                   Logo Design
# 2           Vehicle Wrap Design
# 3         Brand Identity Design
# 4                  Illustration
# 5               Motion Graphics
# 6               Motion Graphics
# 7                Signage Design
# 8          Environmental Design
# 9          Environmental Design
# 10        User Interface Design
# 11               Signage Design
# 12        User Interface Design
# 13          Vehicle Wrap Design
# 14         Environmental Design
# 15                    Animation
# 16               Package Design
# 17               Signage Design
# 18         Product Label Design
# 19              Motion Graphics
# 20        User Interface Design
# 21                  Logo Design
# 22        Brand Identity Design
# 23         Product Label Design
# 24              Motion Graphics
# 25                 UI/UX Design
# 26         Product Label Design
# 27          Vehicle Wrap Design
# 28                  Logo Design
# ...

# %%
data2['Category']=data2['Category'].apply(remove_punctuation)

# %%
data2['Category']=data2['Category'].apply(remove_spaces)

# %%
data2.head(60)
# Out:
#                                          Title Name  \
# 0                        Visual identity. Branding.
# 1                  Thomas Edisons Invention Factory
# 2                 Hellorep.ai onboarding experience
# 3                                    3D Composition
# 4                                    3D Composition
# 5                      Medical service - Mobile app
# 6                                Blent | Case Study
# 7                        Visual identity. Branding.
# 8                  Thomas Edisons Invention Factory
# 9                                Blent | Case Study
# 10  Logo Update for Web3 Platform (Unused for Sale)
# 11                      News Website Design Concept
# 12                               Letter.co Branding
# 13                    Cryptomate: Wallet App design
# 14                       Visual identity. Branding.
# 15                      News Website Design Concept
# 16         Brainwave AI UI Kit - Add New List Modal
# ...

# %%
data2['tags'] = data2['Tags']+','+data2['Category']

# %%
data2['tags'].head(1).all
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of 0    Logo,Package,MotionGraphics,Product,CharacterE...
# Name: tags, dtype: object>

# %%
data2['tags'].head(1).unique()
# Out:
# array(['Logo,Package,MotionGraphics,Product,Character,EnvironmentalDesign'],
#       dtype=object)

# %%
data2.head(60)
# Out:
#                                          Title Name  \
# 0                        Visual identity. Branding.
# 1                  Thomas Edisons Invention Factory
# 2                 Hellorep.ai onboarding experience
# 3                                    3D Composition
# 4                                    3D Composition
# 5                      Medical service - Mobile app
# 6                                Blent | Case Study
# 7                        Visual identity. Branding.
# 8                  Thomas Edisons Invention Factory
# 9                                Blent | Case Study
# 10  Logo Update for Web3 Platform (Unused for Sale)
# 11                      News Website Design Concept
# 12                               Letter.co Branding
# 13                    Cryptomate: Wallet App design
# 14                       Visual identity. Branding.
# 15                      News Website Design Concept
# 16         Brainwave AI UI Kit - Add New List Modal
# ...

# %%
data3 = data2[['Title Name','tags']]

# %%
data3
# Out:
#                              Title Name  \
# 0            Visual identity. Branding.
# 1      Thomas Edisons Invention Factory
# 2     Hellorep.ai onboarding experience
# 3                        3D Composition
# 4                        3D Composition
# ...                                 ...
# 9995                 Blent | Case Study
# 9996      Cryptomate: Wallet App design
# 9997         Visual identity. Branding.
# 9998  Hellorep.ai onboarding experience
# 9999                 Blent | Case Study
#
#                                                    tags
# 0     Logo,Package,MotionGraphics,Product,Character,...
# 1     ComicBook,Character,Poster,Illustration,Brandi...
# 2     WebDesign,Character,Magazine,MotionGraphics,Il...
# 3     Illustration,Package,Character,Magazine,Brandi...
# 4     ComicBook,Typography,WebDesign,Magazine,Illust...
# ...                                                 ...
# 9995  Illustration,Product,Animation,Package,SocialM...
# ...

# %%
data3['tags']=data3['tags'].apply(lambda x:" ".join(x))
# Out:
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/1721511798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['tags']=data3['tags'].apply(lambda x:" ".join(x))

# %%
data3['tags']=data2['tags']
# Out:
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/4059398327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['tags']=data2['tags']

# %%
data3['tags']=data3['tags'].apply(lambda x: x.replace(',',' '))
# Out:
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/3188513947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['tags']=data3['tags'].apply(lambda x: x.replace(',',' '))

# %%
data3['tags']=data3['tags'].apply(lambda x:x.lower())
# Out:
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/3807277675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['tags']=data3['tags'].apply(lambda x:x.lower())

# %%
data3.head(60)
# Out:
#                                          Title Name  \
# 0                        Visual identity. Branding.
# 1                  Thomas Edisons Invention Factory
# 2                 Hellorep.ai onboarding experience
# 3                                    3D Composition
# 4                                    3D Composition
# 5                      Medical service - Mobile app
# 6                                Blent | Case Study
# 7                        Visual identity. Branding.
# 8                  Thomas Edisons Invention Factory
# 9                                Blent | Case Study
# 10  Logo Update for Web3 Platform (Unused for Sale)
# 11                      News Website Design Concept
# 12                               Letter.co Branding
# 13                    Cryptomate: Wallet App design
# 14                       Visual identity. Branding.
# 15                      News Website Design Concept
# 16         Brainwave AI UI Kit - Add New List Modal
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 10000, stop_words ="english")

# %%
vectors =cv.fit_transform(data3['tags']).toarray()

# %%
cv.get_feature_names()
# Out:
# /Users/Anushka/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['animation',
#  'brandidentitydesign',
#  'branding',
#  'character',
#  'comicbook',
#  'environmentaldesign',
#  'illustration',
#  'logo',
#  'logodesign',
#  'magazine',
#  'motiongraphics',
#  'package',
#  'packagedesign',
#  'poster',
#  'posterdesign',
#  'product',
#  'productlabeldesign',
#  'signagedesign',
#  'socialmedia',
#  'tradeshowdisplaydesign',
#  'typography',
#  'uiux',
#  'uiuxdesign',
#  'userexperiencedesign',
#  'userinterfacedesign',
#  'vehiclewrapdesign',
#  'webdesign']

# %%
from nltk.stem.porter import PorterStemmer
pt = PorterStemmer()

# %%
mask = data3.duplicated(subset=['Title Name'])

# %%
mask.unique()
# Out:
# array([False,  True])

# %%
tmask = data3.duplicated(subset=['tags'])

# %%
tmask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
p_data = data3[~tmask]

# %%
p_data
# Out:
#                              Title Name  \
# 0            Visual identity. Branding.
# 1      Thomas Edisons Invention Factory
# 2     Hellorep.ai onboarding experience
# 3                        3D Composition
# 4                        3D Composition
# ...                                 ...
# 9995                 Blent | Case Study
# 9996      Cryptomate: Wallet App design
# 9997         Visual identity. Branding.
# 9998  Hellorep.ai onboarding experience
# 9999                 Blent | Case Study
#
#                                                    tags
# 0     logo package motiongraphics product character ...
# 1     comicbook character poster illustration brandi...
# 2     webdesign character magazine motiongraphics il...
# 3     illustration package character magazine brandi...
# 4     comicbook typography webdesign magazine illust...
# ...                                                 ...
# 9995  illustration product animation package socialm...
# ...

# %% [markdown]
# mask

# %%
data3 = data3[~mask]

# %%
data2['Title Name'].unique()
# Out:
# array(['Visual identity. Branding.', 'Thomas Edisons Invention Factory',
#        'Hellorep.ai onboarding experience', '3D Composition',
#        'Medical service - Mobile app', 'Blent | Case Study',
#        'Logo Update for Web3 Platform (Unused for Sale)',
#        'News Website Design Concept', 'Letter.co Branding',
#        'Cryptomate: Wallet App design',
#        'Brainwave AI UI Kit - Add New List Modal',
#        'illustration animation', 'AVAX Wallet - Page Transitions',
#        'Revolve - Logo Design', "Nike Pickleball - April Fools' Day"],
#       dtype=object)

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(pt.stem(i))
        
    return " ".join(y)

# %%
data3['tags'].apply(stem)
# Out:
# 0     logo packag motiongraph product charact enviro...
# 1     comicbook charact poster illustr brand socialm...
# 2     webdesign charact magazin motiongraph illustr ...
# 3     illustr packag charact magazin brand motiongra...
# 5              logo uiux motiongraph poster motiongraph
# 6               magazin charact logo poster motiongraph
# 10     illustr webdesign brand uiux userinterfacedesign
# 11              comicbook uiux typographi signagedesign
# 12    socialmedia brand typographi poster illustr co...
# 13             charact poster magazin vehiclewrapdesign
# 16       logo packag webdesign typographi packagedesign
# 18    comicbook magazin packag charact productlabeld...
# 21                  comicbook product packag logodesign
# 28     packag product comicbook uiux charact logodesign
# 29       typographi brand product illustr signagedesign
# Name: tags, dtype: object

# %%
vectors.shape
# Out:
# (10000, 27)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity
# Out:
# array([[1.        , 0.28867513, 0.4330127 , ..., 0.40824829, 0.28867513,
#         0.15430335],
#        [0.28867513, 1.        , 0.25      , ..., 0.35355339, 0.375     ,
#         0.40089186],
#        [0.4330127 , 0.25      , 1.        , ..., 0.35355339, 0.375     ,
#         0.53452248],
#        ...,
#        [0.40824829, 0.35355339, 0.35355339, ..., 1.        , 0.35355339,
#         0.37796447],
#        [0.28867513, 0.375     , 0.375     , ..., 0.35355339, 1.        ,
#         0.26726124],
#        [0.15430335, 0.40089186, 0.53452248, ..., 0.37796447, 0.26726124,
#         1.        ]])

# %%
def recommend(movie):
    movie_index = data3[data3['Title_Name']==movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse =True,key = lambda x:x[1])[1:6]
    
    for i in movies_list:
        print(data3.iloc[i[0]].Title_Name)

# %%
recommend('Thomas Edisons Invention Factory')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/2914922445.py in <module>
# ----> 1 recommend('Thomas Edisons Invention Factory')
#
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/600075989.py in recommend(movie)
#       5
#       6     for i in movies_list:
# ----> 7         print(data3.iloc[i[0]].Title_Name)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1521
#    1522             # validate the location
# ...

# %%
data3={ 'Title Name': 'Title_Name'}

# %%
def recommend(movie):
    movie_index = data3[data3['Title_Name']==movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse =True,key = lambda x:x[1])[1:6]
    
    for i in movies_list:
        print(data3.iloc[i[0]].Title_Name)

# %%
recommend('Thomas Edisons Invention Factory')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/2914922445.py in <module>
# ----> 1 recommend('Thomas Edisons Invention Factory')
#
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/600075989.py in recommend(movie)
#       1 def recommend(movie):
# ----> 2     movie_index = data3[data3['Title_Name']==movie].index[0]
#       3     distances = similarity[movie_index]
#       4     movies_list = sorted(list(enumerate(distances)),reverse =True,key = lambda x:x[1])[1:6]
#       5
#
# KeyError: 'Title_Name'

# %%
data3.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/4020059191.py in <module>
# ----> 1 data3.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
data3 = data2[['Title Name','tags']]

# %%
data3
# Out:
#                              Title Name  \
# 0            Visual identity. Branding.
# 1      Thomas Edisons Invention Factory
# 2     Hellorep.ai onboarding experience
# 3                        3D Composition
# 4                        3D Composition
# ...                                 ...
# 9995                 Blent | Case Study
# 9996      Cryptomate: Wallet App design
# 9997         Visual identity. Branding.
# 9998  Hellorep.ai onboarding experience
# 9999                 Blent | Case Study
#
#                                                    tags
# 0     Logo,Package,MotionGraphics,Product,Character,...
# 1     ComicBook,Character,Poster,Illustration,Brandi...
# 2     WebDesign,Character,Magazine,MotionGraphics,Il...
# 3     Illustration,Package,Character,Magazine,Brandi...
# 4     ComicBook,Typography,WebDesign,Magazine,Illust...
# ...                                                 ...
# 9995  Illustration,Product,Animation,Package,SocialM...
# ...

# %%
new_name = {
    'Title Name':'Title_Name'
}

# %%
data3 = data3.rename(columns =new_name)

# %%
data3.head()
# Out:
#                           Title_Name  \
# 0         Visual identity. Branding.
# 1   Thomas Edisons Invention Factory
# 2  Hellorep.ai onboarding experience
# 3                     3D Composition
# 4                     3D Composition
#
#                                                 tags
# 0  Logo,Package,MotionGraphics,Product,Character,...
# 1  ComicBook,Character,Poster,Illustration,Brandi...
# 2  WebDesign,Character,Magazine,MotionGraphics,Il...
# 3  Illustration,Package,Character,Magazine,Brandi...
# 4  ComicBook,Typography,WebDesign,Magazine,Illust...

# %%
data3
# Out:
#                              Title Name  \
# 0            Visual identity. Branding.
# 1      Thomas Edisons Invention Factory
# 2     Hellorep.ai onboarding experience
# 3                        3D Composition
# 4                        3D Composition
# ...                                 ...
# 9995                 Blent | Case Study
# 9996      Cryptomate: Wallet App design
# 9997         Visual identity. Branding.
# 9998  Hellorep.ai onboarding experience
# 9999                 Blent | Case Study
#
#                                                    tags
# 0     logo package motiongraphics product character ...
# 1     comicbook character poster illustration brandi...
# 2     webdesign character magazine motiongraphics il...
# 3     illustration package character magazine brandi...
# 4     comicbook typography webdesign magazine illust...
# ...                                                 ...
# 9995  illustration product animation package socialm...
# ...

# %%
data3['id'] = range(1, len(data3) + 1)
# Out:
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/2618975842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['id'] = range(1, len(data3) + 1)

# %%
data3
# Out:
#                              Title Name  \
# 0            Visual identity. Branding.
# 1      Thomas Edisons Invention Factory
# 2     Hellorep.ai onboarding experience
# 3                        3D Composition
# 4                        3D Composition
# ...                                 ...
# 9995                 Blent | Case Study
# 9996      Cryptomate: Wallet App design
# 9997         Visual identity. Branding.
# 9998  Hellorep.ai onboarding experience
# 9999                 Blent | Case Study
#
#                                                    tags     id
# 0     logo package motiongraphics product character ...      1
# 1     comicbook character poster illustration brandi...      2
# 2     webdesign character magazine motiongraphics il...      3
# 3     illustration package character magazine brandi...      4
# 4     comicbook typography webdesign magazine illust...      5
# ...                                                 ...    ...
# ...

# %%
first_column = data3.pop('id')
data3.insert(0,'id',first_column)

# %%
data3
# Out:
#          id                         Title Name  \
# 0         1         Visual identity. Branding.
# 1         2   Thomas Edisons Invention Factory
# 2         3  Hellorep.ai onboarding experience
# 3         4                     3D Composition
# 4         5                     3D Composition
# ...     ...                                ...
# 9995   9996                 Blent | Case Study
# 9996   9997      Cryptomate: Wallet App design
# 9997   9998         Visual identity. Branding.
# 9998   9999  Hellorep.ai onboarding experience
# 9999  10000                 Blent | Case Study
#
#                                                    tags
# 0     logo package motiongraphics product character ...
# 1     comicbook character poster illustration brandi...
# 2     webdesign character magazine motiongraphics il...
# 3     illustration package character magazine brandi...
# 4     comicbook typography webdesign magazine illust...
# ...                                                 ...
# ...

# %%
def get_similar_titles(title_id):
    # Get the row corresponding to the specified title
    similar_titles_indices = similarities[title_id-1].argsort()[::-1][1:]  # Exclude the title itself
    
    # Get the top 5 similar titles
    top_similar_titles = df.iloc[similar_titles_indices[:5]]
    
    return top_similar_titles

# Example: Get similar titles for title with ID 1
similar_titles = get_similar_titles(1)
print(similar_titles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/1487179061.py in <module>
#       9
#      10 # Example: Get similar titles for title with ID 1
# ---> 11 similar_titles = get_similar_titles(1)
#      12 print(similar_titles)
#
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/1487179061.py in get_similar_titles(title_id)
#       1 def get_similar_titles(title_id):
#       2     # Get the row corresponding to the specified title
# ----> 3     similar_titles_indices = similarities[title_id-1].argsort()[::-1][1:]  # Exclude the title itself
#       4
#       5     # Get the top 5 similar titles
#
# NameError: name 'similarities' is not defined

# %%
data3
# Out:
#          id                         Title Name  \
# 0         1         Visual identity. Branding.
# 1         2   Thomas Edisons Invention Factory
# 2         3  Hellorep.ai onboarding experience
# 3         4                     3D Composition
# 4         5                     3D Composition
# ...     ...                                ...
# 9995   9996                 Blent | Case Study
# 9996   9997      Cryptomate: Wallet App design
# 9997   9998         Visual identity. Branding.
# 9998   9999  Hellorep.ai onboarding experience
# 9999  10000                 Blent | Case Study
#
#                                                    tags
# 0     logo package motiongraphics product character ...
# 1     comicbook character poster illustration brandi...
# 2     webdesign character magazine motiongraphics il...
# 3     illustration package character magazine brandi...
# 4     comicbook typography webdesign magazine illust...
# ...                                                 ...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000, stop_words ="english")

# %%
vectors =cv.fit_transform(data3['tags']).toarray()

# %%
new_name = { 'Title Name':'Title_Name'}
data3 =data3.rename(columns = new_name)

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(pt.stem(i))
        
    return " ".join(y)

# %%
data3['tags'].apply(stem)
# Out:
# 0       logo packag motiongraph product charact enviro...
# 1       comicbook charact poster illustr brand socialm...
# 2       webdesign charact magazin motiongraph illustr ...
# 3       illustr packag charact magazin brand motiongra...
# 4          comicbook typographi webdesign magazin illustr
#                               ...
# 9995      illustr product anim packag socialmedia illustr
# 9996       socialmedia brand logo motiongraph motiongraph
# 9997              packag webdesign motiongraph logodesign
# 9998    uiux packag webdesign magazin charact socialme...
# 9999    poster anim comicbook motiongraph socialmedia ...
# Name: tags, Length: 10000, dtype: object

# %%
vectors =cv.fit_transform(data3['tags']).toarray()

# %%
vectors.shape
# Out:
# (10000, 27)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity
# Out:
# array([[1.        , 0.28867513, 0.4330127 , ..., 0.40824829, 0.28867513,
#         0.15430335],
#        [0.28867513, 1.        , 0.25      , ..., 0.35355339, 0.375     ,
#         0.40089186],
#        [0.4330127 , 0.25      , 1.        , ..., 0.35355339, 0.375     ,
#         0.53452248],
#        ...,
#        [0.40824829, 0.35355339, 0.35355339, ..., 1.        , 0.35355339,
#         0.37796447],
#        [0.28867513, 0.375     , 0.375     , ..., 0.35355339, 1.        ,
#         0.26726124],
#        [0.15430335, 0.40089186, 0.53452248, ..., 0.37796447, 0.26726124,
#         1.        ]])

# %%
def get_similar_titles(title_id):
    # Get the row corresponding to the specified title
    similar_titles_indices = similarity[title_id-1].argsort()[::-1][1:]  # Exclude the title itself
    
    # Get the top 5 similar titles
    top_similar_titles = data3.iloc[similar_titles_indices[:5]]
    
    return top_similar_titles

# Example: Get similar titles for title with ID 1
similar_titles = get_similar_titles(0)
print(similar_titles)
# Out:
#         id                     Title_Name  \
# 7979  7980             Letter.co Branding
# 4785  4786                 3D Composition
# 5008  5009    News Website Design Concept
# 8228  8229  Cryptomate: Wallet App design
# 8829  8830             Letter.co Branding
#
#                                                    tags
# 7979  animation comicbook webdesign poster socialmed...
# 4785  webdesign branding motiongraphics poster socia...
# 5008  webdesign motiongraphics animation comicbook p...
# 8228  package motiongraphics webdesign poster comicb...
# 8829  motiongraphics webdesign poster socialmedia ve...

# %%
# Assuming 'df' is your DataFrame
data3_merged = data3.groupby('Title_Name')['tags'].apply(lambda x: ' '.join(x)).reset_index()

# %%
cv = CountVectorizer(max_features=5000, stop_words="english")

# Transform merged tags into a bag of words representation
X = cv.fit_transform(data3_merged['tags'])

# %%
similarities = cosine_similarity(X)

# %%
def get_similar_titles(title_name):
    # Get the row corresponding to the specified title
    title_row = data3_merged[data3_merged['Title_Name'] == title_name]
    title_id = title_row.index[0]  # Get the index (title ID) of the specified title
    
    similar_titles_indices = similarities[title_id].argsort()[::-1][1:]  # Exclude the title itself
    
    # Get the top 5 similar titles
    top_similar_titles = data3_merged.iloc[similar_titles_indices[:5]]
    
    return top_similar_titles

# %%
data3_merged
# Out:
#                                          Title_Name  \
# 0                                    3D Composition
# 1                    AVAX Wallet - Page Transitions
# 2                                Blent | Case Study
# 3          Brainwave AI UI Kit - Add New List Modal
# 4                     Cryptomate: Wallet App design
# 5                 Hellorep.ai onboarding experience
# 6                                Letter.co Branding
# 7   Logo Update for Web3 Platform (Unused for Sale)
# 8                      Medical service - Mobile app
# 9                       News Website Design Concept
# 10               Nike Pickleball - April Fools' Day
# 11                            Revolve - Logo Design
# 12                 Thomas Edisons Invention Factory
# 13                       Visual identity. Branding.
# 14                           illustration animation
#
#                                                  tags
# 0   illustration package character magazine brandi...
# ...

# %%
get_similar_titles('3D Composition')
# Out:
#                             Title_Name  \
# 10  Nike Pickleball - April Fools' Day
# 6                   Letter.co Branding
# 8         Medical service - Mobile app
# 1       AVAX Wallet - Page Transitions
# 14              illustration animation
#
#                                                  tags
# 10  typography branding product illustration signa...
# 6   socialmedia branding typography poster illustr...
# 8   logo uiux motiongraphics poster motiongraphics...
# 1   comicbook product package logodesign comicbook...
# 14  comicbook magazine package character productla...

# %%
data3_merged['tags'].apply(stem)
# Out:
# 0     illustr packag charact magazin brand motiongra...
# 1     comicbook product packag logodesign comicbook ...
# 2     magazin charact logo poster motiongraph poster...
# 3     logo packag webdesign typographi packagedesign...
# 4     charact poster magazin vehiclewrapdesign logo ...
# 5     webdesign charact magazin motiongraph illustr ...
# 6     socialmedia brand typographi poster illustr co...
# 7     illustr webdesign brand uiux userinterfacedesi...
# 8     logo uiux motiongraph poster motiongraph anim ...
# 9     comicbook uiux typographi signagedesign logo p...
# 10    typographi brand product illustr signagedesign...
# 11    packag product comicbook uiux charact logodesi...
# 12    comicbook charact poster illustr brand socialm...
# 13    logo packag motiongraph product charact enviro...
# 14    comicbook magazin packag charact productlabeld...
# Name: tags, dtype: object

# %%
cv = CountVectorizer(max_features=5000, stop_words="english")

# Transform merged tags into a bag of words representation
X = cv.fit_transform(data3_merged['tags'])

# %%
similarities = cosine_similarity(X)

# %%
def get_similar_titles(title_name):
    # Get the row corresponding to the specified title
    title_row = data3_merged[data3_merged['Title_Name'] == title_name]
    title_id = title_row.index[0]  # Get the index (title ID) of the specified title
    
    similar_titles_indices = similarities[title_id].argsort()[::-1][1:]  # Exclude the title itself
    
    # Get the top 5 similar titles
    top_similar_titles = data3_merged.iloc[similar_titles_indices[:5]]
    
    return top_similar_titles

# %%
get_similar_titles('3D Composition')
# Out:
#                             Title_Name  \
# 10  Nike Pickleball - April Fools' Day
# 6                   Letter.co Branding
# 8         Medical service - Mobile app
# 1       AVAX Wallet - Page Transitions
# 14              illustration animation
#
#                                                  tags
# 10  typography branding product illustration signa...
# 6   socialmedia branding typography poster illustr...
# 8   logo uiux motiongraphics poster motiongraphics...
# 1   comicbook product package logodesign comicbook...
# 14  comicbook magazine package character productla...

# %%
import pickle as pk

# %%
pk.dump(data3_merged.to_dict(),open('data.pkl','wb'))

# %%
data3_merged.to_dict()
# Out:
# {'Title_Name': {0: '3D Composition',
#   1: 'AVAX Wallet - Page Transitions',
#   2: 'Blent | Case Study',
#   3: 'Brainwave AI UI Kit - Add New List Modal',
#   4: 'Cryptomate: Wallet App design',
#   5: 'Hellorep.ai onboarding experience',
#   6: 'Letter.co Branding',
#   7: 'Logo Update for Web3 Platform (Unused for Sale)',
#   8: 'Medical service - Mobile app',
#   9: 'News Website Design Concept',
#   10: "Nike Pickleball - April Fools' Day",
#   11: 'Revolve - Logo Design',
#   12: 'Thomas Edisons Invention Factory',
#   13: 'Visual identity. Branding.',
#   14: 'illustration animation'},
# ...

# %%
pk.dump(data3_merged.to_dict(),open('dataset.pkl','wb'))

# %%
pk.dump(similarities,open('similarities.pkl'),'wb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/6t/ljxf9tfd5j32hqvb_k5w289r0000gn/T/ipykernel_51877/3526861548.py in <module>
# ----> 1 pk.dump(similarities,open('similarities.pkl'),'wb')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'similarities.pkl'

# %%
pk.dump(similarities,open('similarities.pkl','wb'))

# %%
result_dict = dict(zip(data3_merged['Title_Name'], data3_merged['tags']))

# %%
title_dict = {idx: title for idx, title in enumerate(data3_merged['Title_Name'], start=1)}
tags_dict = {idx: tags for idx, tags in enumerate(data3_merged['tags'], start=1)}

result_dict = {'title_name': title_dict, 'tags': tags_dict}

# %%
pk.dump(result_dict,open('required_data.pkl','wb'))
